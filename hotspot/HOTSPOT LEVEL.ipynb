# %%
import pandas as pd

df = pd.read_csv("coal_dataset_10k_5years.csv")

df = df.dropna(subset=['CO2_ppm', 'CH4_ppm', 'PM2_5', 'PM10'])

df['Emission_Score'] = (
    0.4 * df['CO2_ppm'] +
    0.3 * df['CH4_ppm'] +
    0.15 * df['PM2_5'] +
    0.15 * df['PM10']
)

mean_score = df['Emission_Score'].mean()
std_score = df['Emission_Score'].std()
low_thresh = mean_score - 0.5 * std_score
high_thresh = mean_score + 0.5 * std_score

def classify_emission(x):
    if x > high_thresh:
        return 'Red'
    elif x > low_thresh:
        return 'Orange'
    else:
        return 'Yellow'

df['Hotspot_Level'] = df['Emission_Score'].apply(classify_emission)

top_red = df[df['Hotspot_Level'] == 'Red'].nlargest(10, 'Emission_Score')[['State', 'District', 'Mine_Name', 'Emission_Score', 'Latitude', 'Longitude']]
top_orange = df[df['Hotspot_Level'] == 'Orange'].nlargest(10, 'Emission_Score')[['State', 'District', 'Mine_Name', 'Emission_Score', 'Latitude', 'Longitude']]
top_yellow = df[df['Hotspot_Level'] == 'Yellow'].nlargest(10, 'Emission_Score')[['State', 'District', 'Mine_Name', 'Emission_Score', 'Latitude', 'Longitude']]

output_data = {
    "thresholds": {
        "low_threshold": round(low_thresh, 2),
        "high_threshold": round(high_thresh, 2)
    },
    "top_red_hotspots": top_red.to_dict(orient='records'),
    "top_orange_hotspots": top_orange.to_dict(orient='records'),
    "top_yellow_hotspots": top_yellow.to_dict(orient='records')
}

output_data
# Out:
# {'thresholds': {'low_threshold': np.float64(188.32),
#   'high_threshold': np.float64(201.32)},
#  'top_red_hotspots': [{'State': 'Chhattisgarh',
#    'District': 'Korba',
#    'Mine_Name': 'Kusmunda',
#    'Emission_Score': 241.38173384760327,
#    'Latitude': 22.25,
#    'Longitude': 82.52},
#   {'State': 'Chhattisgarh',
#    'District': 'Surguja',
#    'Mine_Name': 'Bhatgaon',
#    'Emission_Score': 239.2657352874356,
#    'Latitude': 23.037,
#    'Longitude': 82.857},
#   {'State': 'Chhattisgarh',
#    'District': 'Korba',
#    'Mine_Name': 'Kusmunda',
#    'Emission_Score': 239.14679312718695,
#    'Latitude': 22.25,
#    'Longitude': 82.52},
#   {'State': 'Chhattisgarh',
#    'District': 'Korba',
#    'Mine_Name': 'Gevra',
#    'Emission_Score': 238.8434771561069,
#    'Latitude': 22.331,
#    'Longitude': 82.614},
#   {'State': 'Odisha',
#    'District': 'Angul',
#    'Mine_Name': 'Bhubaneswari',
#    'Emission_Score': 238.5720729198756,
#    'Latitude': 20.94,
#    'Longitude': 85.19},
#   {'State': 'Chhattisgarh',
#    'District': 'Korba',
#    'Mine_Name': 'Kusmunda',
#    'Emission_Score': 236.76231505143846,
#    'Latitude': 22.25,
#    'Longitude': 82.52},
#   {'State': 'Odisha',
#    'District': 'Jharsuguda',
#    'Mine_Name': 'Lakhanpur',
#    'Emission_Score': 236.72622535423542,
#    'Latitude': 21.85,
#    'Longitude': 83.87},
#   {'State': 'Odisha',
#    'District': 'Angul',
#    'Mine_Name': 'Talcher',
#    'Emission_Score': 236.1793164804713,
#    'Latitude': 20.95,
#    'Longitude': 85.23},
#   {'State': 'Jharkhand',
#    'District': 'Bokaro',
#    'Mine_Name': 'Kathara',
#    'Emission_Score': 235.5820358749392,
#    'Latitude': 23.91,
#    'Longitude': 85.92},
#   {'State': 'Chhattisgarh',
#    'District': 'Surguja',
#    'Mine_Name': 'Bhatgaon',
#    'Emission_Score': 235.324901621778,
#    'Latitude': 23.037,
#    'Longitude': 82.857}],
#  'top_orange_hotspots': [{'State': 'Odisha',
#    'District': 'Jharsuguda',
#    'Mine_Name': 'Lakhanpur',
#    'Emission_Score': 201.32000805343566,
#    'Latitude': 21.85,
#    'Longitude': 83.87},
#   {'State': 'Odisha',
#    'District': 'Angul',
#    'Mine_Name': 'Talcher',
#    'Emission_Score': 201.31870827861007,
#    'Latitude': 20.95,
#    'Longitude': 85.23},
#   {'State': 'Odisha',
#    'District': 'Jharsuguda',
#    'Mine_Name': 'Lakhanpur',
#    'Emission_Score': 201.31375800324398,
#    'Latitude': 21.85,
#    'Longitude': 83.87},
#   {'State': 'Chhattisgarh',
#    'District': 'Korba',
#    'Mine_Name': 'Kusmunda',
#    'Emission_Score': 201.30932204435052,
#    'Latitude': 22.25,
#    'Longitude': 82.52},
#   {'State': 'Chhattisgarh',
#    'District': 'Korba',
#    'Mine_Name': 'Gevra',
#    'Emission_Score': 201.2989209252359,
#    'Latitude': 22.331,
#    'Longitude': 82.614},
#   {'State': 'Jharkhand',
#    'District': 'Bokaro',
#    'Mine_Name': 'Kathara',
#    'Emission_Score': 201.29562083335844,
#    'Latitude': 23.91,
#    'Longitude': 85.92},
#   {'State': 'Chhattisgarh',
#    'District': 'Korba',
#    'Mine_Name': 'Gevra',
#    'Emission_Score': 201.29471185372051,
#    'Latitude': 22.331,
#    'Longitude': 82.614},
#   {'State': 'Jharkhand',
#    'District': 'Dhanbad',
#    'Mine_Name': 'Bhowra',
#    'Emission_Score': 201.29276039863348,
#    'Latitude': 23.75,
#    'Longitude': 86.43},
#   {'State': 'Odisha',
#    'District': 'Angul',
#    'Mine_Name': 'Bhubaneswari',
#    'Emission_Score': 201.29023939912088,
#    'Latitude': 20.94,
#    'Longitude': 85.19},
#   {'State': 'Chhattisgarh',
#    'District': 'Korba',
#    'Mine_Name': 'Gevra',
#    'Emission_Score': 201.2899903022789,
#    'Latitude': 22.331,
#    'Longitude': 82.614}],
#  'top_yellow_hotspots': [{'State': 'Jharkhand',
#    'District': 'Bokaro',
#    'Mine_Name': 'Kathara',
#    'Emission_Score': 188.31667404637602,
#    'Latitude': 23.91,
#    'Longitude': 85.92},
#   {'State': 'Chhattisgarh',
#    'District': 'Raigarh',
#    'Mine_Name': 'Dharamjaigarh',
#    'Emission_Score': 188.30026019698948,
#    'Latitude': 22.308,
#    'Longitude': 83.285},
#   {'State': 'Chhattisgarh',
#    'District': 'Surguja',
#    'Mine_Name': 'Bhatgaon',
#    'Emission_Score': 188.29739497123305,
#    'Latitude': 23.037,
#    'Longitude': 82.857},
#   {'State': 'Odisha',
#    'District': 'Jharsuguda',
#    'Mine_Name': 'Lakhanpur',
#    'Emission_Score': 188.29299121991264,
#    'Latitude': 21.85,
#    'Longitude': 83.87},
#   {'State': 'Odisha',
#    'District': 'Angul',
#    'Mine_Name': 'Bhubaneswari',
#    'Emission_Score': 188.2924485557967,
#    'Latitude': 20.94,
#    'Longitude': 85.19},
#   {'State': 'Odisha',
#    'District': 'Jharsuguda',
#    'Mine_Name': 'Lakhanpur',
#    'Emission_Score': 188.29126966109354,
#    'Latitude': 21.85,
#    'Longitude': 83.87},
#   {'State': 'Jharkhand',
#    'District': 'Dhanbad',
#    'Mine_Name': 'Bhowra',
#    'Emission_Score': 188.2876702077488,
#    'Latitude': 23.75,
#    'Longitude': 86.43},
#   {'State': 'Jharkhand',
#    'District': 'Ramgarh',
#    'Mine_Name': 'Rajrappa',
#    'Emission_Score': 188.2851426519692,
#    'Latitude': 23.68,
#    'Longitude': 85.54},
#   {'State': 'Chhattisgarh',
#    'District': 'Raigarh',
#    'Mine_Name': 'Dharamjaigarh',
#    'Emission_Score': 188.2843560130049,
#    'Latitude': 22.308,
#    'Longitude': 83.285},
#   {'State': 'Jharkhand',
#    'District': 'Dhanbad',
#    'Mine_Name': 'Bhowra',
#    'Emission_Score': 188.28404196912808,
#    'Latitude': 23.75,
#    'Longitude': 86.43}]}
