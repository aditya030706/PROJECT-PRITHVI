# %%
import pandas as pd
import numpy as np

df = pd.read_csv("coal_dataset_10k_5years.csv")

gas_columns = ['CO2_ppm', 'CH4_ppm', 'SO2_ppm', 'NOx_ppm']
meta_columns = ['State', 'District', 'Mine_Name', 'Latitude', 'Longitude']

df = df.dropna(subset=gas_columns + meta_columns)

weights = {
    'CO2_ppm': 0.5,
    'CH4_ppm': 0.3,
    'SO2_ppm': 0.1,
    'NOx_ppm': 0.1
}

df['Emission_Score'] = (
    weights['CO2_ppm'] * df['CO2_ppm'] +
    weights['CH4_ppm'] * df['CH4_ppm'] +
    weights['SO2_ppm'] * df['SO2_ppm'] +
    weights['NOx_ppm'] * df['NOx_ppm']
)

mine_avg = (
    df.groupby(meta_columns)[['CO2_ppm', 'CH4_ppm', 'SO2_ppm', 'NOx_ppm', 'Emission_Score']]
    .mean()
    .reset_index()
)

threshold = mine_avg['Emission_Score'].quantile(0.9)
mine_avg['Hotspot'] = np.where(mine_avg['Emission_Score'] >= threshold, 'Yes', 'No')

output_data = {
    "hotspot_threshold": round(threshold, 2),
    "average_gas_levels": mine_avg[['CO2_ppm', 'CH4_ppm', 'SO2_ppm', 'NOx_ppm']].mean().round(2).to_dict(),
    "hotspot_data": mine_avg.to_dict(orient='records')
}

mine_avg.to_csv("hotspot_data.csv", index=False)

output_data
# Out:
# {'hotspot_threshold': np.float64(217.94),
#  'average_gas_levels': {'CO2_ppm': 425.1,
#   'CH4_ppm': 1.95,
#   'SO2_ppm': 13.99,
#   'NOx_ppm': 26.04},
#  'hotspot_data': [{'State': 'Chhattisgarh',
#    'District': 'Korba',
#    'Mine_Name': 'Dipka',
#    'Latitude': 22.418,
#    'Longitude': 82.721,
#    'CO2_ppm': 423.9587114601761,
#    'CH4_ppm': 1.9556750405094592,
#    'SO2_ppm': 14.278576765152696,
#    'NOx_ppm': 26.127390408500553,
#    'Emission_Score': 216.60665495960617,
#    'Hotspot': 'No'},
#   {'State': 'Chhattisgarh',
#    'District': 'Korba',
#    'Mine_Name': 'Gevra',
#    'Latitude': 22.331,
#    'Longitude': 82.614,
#    'CO2_ppm': 424.7482283507449,
#    'CH4_ppm': 1.952296468524279,
#    'SO2_ppm': 13.646888977704725,
#    'NOx_ppm': 26.352602330125595,
#    'Emission_Score': 216.95975224671278,
#    'Hotspot': 'No'},
#   {'State': 'Chhattisgarh',
#    'District': 'Korba',
#    'Mine_Name': 'Kusmunda',
#    'Latitude': 22.25,
#    'Longitude': 82.52,
#    'CO2_ppm': 424.85901765354305,
#    'CH4_ppm': 1.9312742211607117,
#    'SO2_ppm': 14.028397437683676,
#    'NOx_ppm': 25.47653844640932,
#    'Emission_Score': 216.95938468152903,
#    'Hotspot': 'No'},
#   {'State': 'Chhattisgarh',
#    'District': 'Raigarh',
#    'Mine_Name': 'Dharamjaigarh',
#    'Latitude': 22.308,
#    'Longitude': 83.285,
#    'CO2_ppm': 424.8739402242905,
#    'CH4_ppm': 1.9411553856749162,
#    'SO2_ppm': 13.803672687661324,
#    'NOx_ppm': 26.00363125510053,
#    'Emission_Score': 217.0000471221239,
#    'Hotspot': 'No'},
#   {'State': 'Chhattisgarh',
#    'District': 'Raigarh',
#    'Mine_Name': 'Jampali',
#    'Latitude': 21.977,
#    'Longitude': 83.352,
#    'CO2_ppm': 426.8677372833859,
#    'CH4_ppm': 1.9499362295553881,
#    'SO2_ppm': 13.608998195239833,
#    'NOx_ppm': 26.014210631529245,
#    'Emission_Score': 217.98117039323648,
#    'Hotspot': 'Yes'},
#   {'State': 'Chhattisgarh',
#    'District': 'Surguja',
#    'Mine_Name': 'Bhatgaon',
#    'Latitude': 23.037,
#    'Longitude': 82.857,
#    'CO2_ppm': 425.34601832784705,
#    'CH4_ppm': 1.946019606009236,
#    'SO2_ppm': 14.039592179599932,
#    'NOx_ppm': 26.18590379120397,
#    'Emission_Score': 217.2793646428067,
#    'Hotspot': 'No'},
#   {'State': 'Jharkhand',
#    'District': 'Bokaro',
#    'Mine_Name': 'Kargali',
#    'Latitude': 23.82,
#    'Longitude': 85.92,
#    'CO2_ppm': 425.4242290763934,
#    'CH4_ppm': 1.9451639291052614,
#    'SO2_ppm': 14.148239106990074,
#    'NOx_ppm': 25.790698225172413,
#    'Emission_Score': 217.2895574501445,
#    'Hotspot': 'No'},
#   {'State': 'Jharkhand',
#    'District': 'Bokaro',
#    'Mine_Name': 'Kathara',
#    'Latitude': 23.91,
#    'Longitude': 85.92,
#    'CO2_ppm': 424.00685420815694,
#    'CH4_ppm': 1.9593993183905871,
#    'SO2_ppm': 14.266586604717025,
#    'NOx_ppm': 26.507273067163418,
#    'Emission_Score': 216.6686328667837,
#    'Hotspot': 'No'},
#   {'State': 'Jharkhand',
#    'District': 'Dhanbad',
#    'Mine_Name': 'Bhowra',
#    'Latitude': 23.75,
#    'Longitude': 86.43,
#    'CO2_ppm': 422.9437415461973,
#    'CH4_ppm': 1.9595679001302102,
#    'SO2_ppm': 13.911535701033483,
#    'NOx_ppm': 25.51979643057682,
#    'Emission_Score': 216.00287435629875,
#    'Hotspot': 'No'},
#   {'State': 'Jharkhand',
#    'District': 'Dhanbad',
#    'Mine_Name': 'Jharia',
#    'Latitude': 23.77,
#    'Longitude': 86.42,
#    'CO2_ppm': 424.8696167637186,
#    'CH4_ppm': 1.948791448104524,
#    'SO2_ppm': 13.99757082004732,
#    'NOx_ppm': 25.49683185949238,
#    'Emission_Score': 216.96888608424464,
#    'Hotspot': 'No'},
#   {'State': 'Jharkhand',
#    'District': 'Ramgarh',
#    'Mine_Name': 'Rajrappa',
#    'Latitude': 23.68,
#    'Longitude': 85.54,
#    'CO2_ppm': 425.42396176011823,
#    'CH4_ppm': 1.9625637555053808,
#    'SO2_ppm': 14.226730036110402,
#    'NOx_ppm': 26.38398892330469,
#    'Emission_Score': 217.36182190265225,
#    'Hotspot': 'No'},
#   {'State': 'Odisha',
#    'District': 'Angul',
#    'Mine_Name': 'Bhubaneswari',
#    'Latitude': 20.94,
#    'Longitude': 85.19,
#    'CO2_ppm': 425.52557766008516,
#    'CH4_ppm': 1.9465782128183235,
#    'SO2_ppm': 14.096912258046807,
#    'NOx_ppm': 26.535676612084092,
#    'Emission_Score': 217.41002118090117,
#    'Hotspot': 'No'},
#   {'State': 'Odisha',
#    'District': 'Angul',
#    'Mine_Name': 'Talcher',
#    'Latitude': 20.95,
#    'Longitude': 85.23,
#    'CO2_ppm': 423.6055553034553,
#    'CH4_ppm': 1.9517395028416102,
#    'SO2_ppm': 14.133457822994346,
#    'NOx_ppm': 26.29010339066637,
#    'Emission_Score': 216.43065562394617,
#    'Hotspot': 'No'},
#   {'State': 'Odisha',
#    'District': 'Jharsuguda',
#    'Mine_Name': 'Lakhanpur',
#    'Latitude': 21.85,
#    'Longitude': 83.87,
#    'CO2_ppm': 427.402118797692,
#    'CH4_ppm': 1.9460502671274558,
#    'SO2_ppm': 13.553353546591993,
#    'NOx_ppm': 26.37860473510591,
#    'Emission_Score': 218.27807030715405,
#    'Hotspot': 'Yes'},
#   {'State': 'Odisha',
#    'District': 'Sundargarh',
#    'Mine_Name': 'Basundhara',
#    'Latitude': 21.93,
#    'Longitude': 83.73,
#    'CO2_ppm': 426.67160095913005,
#    'CH4_ppm': 1.9558089474976859,
#    'SO2_ppm': 14.050929501565427,
#    'NOx_ppm': 25.509169408150438,
#    'Emission_Score': 217.87855305478593,
#    'Hotspot': 'No'}]}
